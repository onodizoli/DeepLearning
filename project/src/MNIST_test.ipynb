# %%
import matplotlib
import pylab
import numpy as np
# %matplotlib inline
from project_mnist import test_dropout, test_dropout_MNIST_conv
from project_utils import load_mnist
from pylab import imshow, show, cm
# Out:
# Using gpu device 0: GRID K520

# %% [markdown]
# # MNIST different activations

# %% [markdown]
# We implemented a 2 layer peceptron with 800 neurons each, dropout rate is 0.5, learning schedule 250-125-20, and 3 different activation: relu, sigmoid, tanh.

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[250,125,20],
             batch_size=128, n_hidden=800, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.728261 %
#      epoch 1, minibatch 421/421, test error of best model 74.649439 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 72.010870 %
#      epoch 2, minibatch 421/421, test error of best model 71.744792 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 66.066576 %
#      epoch 3, minibatch 421/421, test error of best model 65.895433 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 37.635870 %
#      epoch 4, minibatch 421/421, test error of best model 40.534856 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[250,125,20],
             batch_size=128, n_hidden=800, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='tanh', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 9.935462 %
#      epoch 1, minibatch 421/421, test error of best model 12.099359 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 8.729620 %
#      epoch 2, minibatch 421/421, test error of best model 9.935897 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 8.084239 %
#      epoch 3, minibatch 421/421, test error of best model 9.124599 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 7.778533 %
#      epoch 4, minibatch 421/421, test error of best model 8.844151 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[250,125,20],
             batch_size=128, n_hidden=800, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='sigmoid', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 48.352582 %
#      epoch 1, minibatch 421/421, test error of best model 47.105369 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 28.770380 %
#      epoch 2, minibatch 421/421, test error of best model 33.153045 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 19.701087 %
#      epoch 3, minibatch 421/421, test error of best model 21.414263 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 19.684103 %
#      epoch 4, minibatch 421/421, test error of best model 21.955128 %
# ...

# %% [markdown]
# # MNIST varying total number of neurons

# %% [markdown]
# In this experiment the total number of neurons were changed to be 200, 400, 800 and 1600. All models udes relu activation, 100-100-20 schudle, 0.1 starting learning rate, dropout rate 0.5. The experiment were done with and withou using DropConnect.

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=100, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 75.407609 %
#      epoch 1, minibatch 421/421, test error of best model 75.641026 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 72.486413 %
#      epoch 2, minibatch 421/421, test error of best model 72.375801 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 71.059783 %
#      epoch 3, minibatch 421/421, test error of best model 70.933494 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 69.361413 %
#      epoch 4, minibatch 421/421, test error of best model 69.170673 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=200, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.660326 %
#      epoch 1, minibatch 421/421, test error of best model 74.779647 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 72.231658 %
#      epoch 2, minibatch 421/421, test error of best model 72.365785 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 70.414402 %
#      epoch 3, minibatch 421/421, test error of best model 70.673077 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 67.883832 %
#      epoch 4, minibatch 421/421, test error of best model 68.108974 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.490489 %
#      epoch 1, minibatch 421/421, test error of best model 74.399038 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 68.478261 %
#      epoch 2, minibatch 421/421, test error of best model 68.279247 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 58.423913 %
#      epoch 3, minibatch 421/421, test error of best model 58.223157 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 40.149457 %
#      epoch 4, minibatch 421/421, test error of best model 42.487981 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=800, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.728261 %
#      epoch 1, minibatch 421/421, test error of best model 74.649439 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 72.010870 %
#      epoch 2, minibatch 421/421, test error of best model 71.764824 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 65.981658 %
#      epoch 3, minibatch 421/421, test error of best model 65.835337 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 37.601902 %
#      epoch 4, minibatch 421/421, test error of best model 40.554888 %
# ...

# %% [markdown]
# ### No dropconnect

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=100, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p=1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.133832 %
#      epoch 1, minibatch 421/421, test error of best model 73.808093 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 66.270380 %
#      epoch 2, minibatch 421/421, test error of best model 66.105769 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 24.609375 %
#      epoch 3, minibatch 421/421, test error of best model 25.220353 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 8.746603 %
#      epoch 4, minibatch 421/421, test error of best model 9.955929 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=200, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p=1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 72.741168 %
#      epoch 1, minibatch 421/421, test error of best model 72.596154 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 56.640625 %
#      epoch 2, minibatch 421/421, test error of best model 57.642228 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 18.172554 %
#      epoch 3, minibatch 421/421, test error of best model 20.893429 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 8.576766 %
#      epoch 4, minibatch 421/421, test error of best model 9.725561 %
# ...

# %%
test_dropout(learning_rate_zero=0.05, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p=1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 76.002038 %
#      epoch 1, minibatch 421/421, test error of best model 75.741186 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 73.284647 %
#      epoch 2, minibatch 421/421, test error of best model 72.966747 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 54.500679 %
#      epoch 3, minibatch 421/421, test error of best model 55.348558 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 34.425951 %
#      epoch 4, minibatch 421/421, test error of best model 37.179487 %
# ...

# %%
test_dropout(learning_rate_zero=0.01, L1_reg=0.00, L2_reg=0.00, n_epochs=[100,100,20],
             batch_size=128, n_hidden=800, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p=1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 78.566576 %
#      epoch 1, minibatch 421/421, test error of best model 77.804487 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 76.443614 %
#      epoch 2, minibatch 421/421, test error of best model 75.921474 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 74.490489 %
#      epoch 3, minibatch 421/421, test error of best model 74.609375 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 73.131793 %
#      epoch 4, minibatch 421/421, test error of best model 73.657853 %
# ...

# %%
import matplotlib.pyplot as plt
Y = [3.114984, 2.634215, 2.273638, 2.083333]
X = [200, 400, 800, 1600]
Y2 = [2.554087, 2.233574, 2.183494, 2.473958]
fig = plt.figure()
plt.plot(X, Y, 'r', X, Y2, 'b') 
plt.ylabel('Test Error %')
plt.xlabel('Hidden units')
fig.suptitle('Dropout accuracy', fontsize=18)
plt.legend(('DropConnect','No DropConnect'))
plt.show()

# %% [markdown]
# # MNIST varying dropout rate

# %% [markdown]
# This network is a two hidden layerd MLP, 400 neurons each, relu activation, 0.1 initial learning rate, 700-200-20 schedule, dropconnect changed from 0.1 to 0.9

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 86.854620 %
#      epoch 1, minibatch 421/421, test error of best model 85.967548 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 81.029212 %
#      epoch 2, minibatch 421/421, test error of best model 80.298478 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 79.942255 %
#      epoch 3, minibatch 421/421, test error of best model 79.276843 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 76.664402 %
#      epoch 4, minibatch 421/421, test error of best model 76.312099 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.2)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 78.702446 %
#      epoch 1, minibatch 421/421, test error of best model 78.145032 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 73.250679 %
#      epoch 2, minibatch 421/421, test error of best model 73.778045 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 70.923913 %
#      epoch 3, minibatch 421/421, test error of best model 71.033654 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 69.344429 %
#      epoch 4, minibatch 421/421, test error of best model 69.160657 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.4)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.660326 %
#      epoch 1, minibatch 421/421, test error of best model 74.559295 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 71.620245 %
#      epoch 2, minibatch 421/421, test error of best model 71.574519 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 66.338315 %
#      epoch 3, minibatch 421/421, test error of best model 66.856971 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 60.529891 %
#      epoch 4, minibatch 421/421, test error of best model 60.767228 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.5)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.490489 %
#      epoch 1, minibatch 421/421, test error of best model 74.399038 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 68.478261 %
#      epoch 2, minibatch 421/421, test error of best model 68.279247 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 58.423913 %
#      epoch 3, minibatch 421/421, test error of best model 58.223157 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 40.149457 %
#      epoch 4, minibatch 421/421, test error of best model 42.487981 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.6)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 74.643342 %
#      epoch 1, minibatch 421/421, test error of best model 74.559295 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 65.760870 %
#      epoch 2, minibatch 421/421, test error of best model 66.085737 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 43.563179 %
#      epoch 3, minibatch 421/421, test error of best model 45.492788 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 19.497283 %
#      epoch 4, minibatch 421/421, test error of best model 23.517628 %
# ...

# %%
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.9)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 73.318614 %
#      epoch 1, minibatch 421/421, test error of best model 73.467548 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 45.074728 %
#      epoch 2, minibatch 421/421, test error of best model 47.135417 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 14.215353 %
#      epoch 3, minibatch 421/421, test error of best model 16.276042 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 7.625679 %
#      epoch 4, minibatch 421/421, test error of best model 8.764022 %
# ...

# %%
import matplotlib.pyplot as plt
Y = [5.544471, 3.094952, 2.343750 , 1.852965, 1.732772, 1.943109]
X = [0.1, 0.2, 0.4, 0.5, 0.6, 0.9]
fig = plt.figure()
plt.plot(X, Y, 'r') 
plt.ylabel('Test Error %')
plt.xlabel('% of Element kept')
fig.suptitle('Dropout accuracy', fontsize=18)
plt.xlim(0,0.9)
plt.ylim(1.4,5)
plt.show()

# %% [markdown]
# # Testing with cropping

# %% [markdown]
# In the paper the authors used cropping to increase the testset and decrease error rate, however, due to time constrains we were not able to test out this setting couse the train time for a single model increased to a day

# %%
#cropped
test_dropout(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,20],
             batch_size=128, n_hidden=400, n_hiddenLayers=2,
             verbose=True, smaller_set=True, activation ='relu', momentum =0.9, p = 0.5)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 1, minibatch 1687/1687, validation error 63.661430 %
#      epoch 1, minibatch 1687/1687, test error of best model 63.824619 %
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# ...

# %% [markdown]
# # ConvNET

# %% [markdown]
# The author experimented with a convolutional networkk as well. The network consisted of two convolutional layers with 5x5 kernel size and 32 and 64 kernels. The output of the kernels was fed into a 150 neurons hidden layer with DropConnect. Initial learning rate was 0.1, 700-200-100 schedule.

# %%
test_dropout_MNIST_conv(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[700,200,100],
             batch_size=128, n_hidden=150, n_hiddenLayers=1, verbose=True, activation = 'tanh', momentum=1)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# epoch 1, minibatch 421/421, validation error 5.146060 %
#      epoch 1, minibatch 421/421, test error of best model 5.999599 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 2, minibatch 421/421, validation error 2.904212 %
#      epoch 2, minibatch 421/421, test error of best model 3.625801 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 3, minibatch 421/421, validation error 2.377717 %
#      epoch 3, minibatch 421/421, test error of best model 2.624199 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 4, minibatch 421/421, validation error 2.038043 %
#      epoch 4, minibatch 421/421, test error of best model 1.993189 %
# ...

# %% [markdown]
# I also ran the same settings on the augmented dataset with cropping. The learning schedule was decreased to 200-125-20, because due to the increased amaunt of data, the learning time trippled.

# %%
# Cropped
test_dropout_MNIST_conv(learning_rate_zero=0.1, L1_reg=0.00, L2_reg=0.00, n_epochs=[200,125,20],
             batch_size=128, n_hidden=150, n_hiddenLayers=1, verbose=True, activation = 'tanh', momentum=1, croped = True)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# epoch 1, minibatch 1687/1687, validation error 4.712567 %
#      epoch 1, minibatch 1687/1687, test error of best model 4.149139 %
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# ...
