# %%
from project_norb import test_dropout_model2

test_dropout_model2(learning_rate_zero=0.001, L1_reg=0.00, L2_reg=0.00, n_epochs=[60,10,5],
             batch_size=128, n_hidden=512, n_hiddenLayers=1,
             verbose=True, activation = 'relu', momentum=0.9)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# Data already unpacked
# Data already unpacked
# Data already unpacked
# Data already unpacked
# ... building the model
# project_nn.py:492: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   subsample=conv_stride
# project_nn.py:576: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   filter_flip=False
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# ...

# %% [markdown]
# ### I increased the learning rate and changed the activation function to tanh to observe and increased response by th network.

# %%
from project_norb import test_dropout_model2

test_dropout_model2(learning_rate_zero=0.05, L1_reg=0.00, L2_reg=0.00, n_epochs=[60,10,5],
             batch_size=128, n_hidden=512, n_hiddenLayers=1,
             verbose=True, activation = 'tanh', momentum=0.9)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# Data already unpacked
# Data already unpacked
# Data already unpacked
# Data already unpacked
# ... building the model
# project_nn.py:492: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   subsample=conv_stride
# project_nn.py:576: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   filter_flip=False
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# ...
