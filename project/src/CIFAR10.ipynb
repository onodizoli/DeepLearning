# %% [markdown]
# # First model with paramaters as specified in the paper

# %%
from project_cifar10 import test_dropout_model1

test_dropout_model1(learning_rate_zero=0.001, L1_reg=0.00, L2_reg=0.00, n_epochs=[150,0,0],
                    batch_size=128, n_hidden=64, n_hiddenLayers=1,
                    verbose=True, activation='relu', momentum=0.9)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# Data already unpacked
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# epoch 1, minibatch 312/312, validation error 89.863782 %
#      epoch 1, minibatch 312/312, test error of best model 90.004006 %
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# epoch 2, minibatch 312/312, validation error 89.863782 %
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# epoch 3, minibatch 312/312, validation error 89.863782 %
# training @ iter =  1000
# training @ iter =  1100
# ...

# %% [markdown]
# ### I increased the learning rate 30x to see a more drastic reaction by the network.

# %%
from project_cifar10 import test_dropout_model1

test_dropout_model1(learning_rate_zero=0.03, L1_reg=0.00, L2_reg=0.00, n_epochs=[150,0,0],
                    batch_size=128, n_hidden=64, n_hiddenLayers=1,
                    verbose=True, activation='relu', momentum=0.9)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# Data already unpacked
# ... building the model
# project_nn.py:492: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   subsample=conv_stride
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# epoch 1, minibatch 312/312, validation error 84.655449 %
#      epoch 1, minibatch 312/312, test error of best model 84.505208 %
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# epoch 2, minibatch 312/312, validation error 83.583734 %
# ...

# %% [markdown]
# # Second model with parameters as specified in the paper
# ### Due to time constraints, however, the total number of epochs has been reduced and the learning rate has been increased.

# %%
from project_cifar10 import test_dropout_model2

test_dropout_model2(learning_rate_zero=0.001, L1_reg=0.00, L2_reg=0.00, n_epochs=[60,10,5],
                    batch_size=128, n_hidden=128, n_hiddenLayers=1,
                    verbose=True, activation='relu', momentum=0.9)
# Out:
# Data already unpacked
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# epoch 1, minibatch 312/312, validation error 89.873798 %
#      epoch 1, minibatch 312/312, test error of best model 90.054087 %
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# epoch 2, minibatch 312/312, validation error 89.663462 %
#      epoch 2, minibatch 312/312, test error of best model 89.853766 %
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# epoch 3, minibatch 312/312, validation error 87.610176 %
#      epoch 3, minibatch 312/312, test error of best model 87.650240 %
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 4, minibatch 312/312, validation error 84.585337 %
#      epoch 4, minibatch 312/312, test error of best model 84.405048 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# ...

# %%
from project_cifar10 import test_dropout_model2

test_dropout_model2(learning_rate_zero=0.05, L1_reg=0.00, L2_reg=0.00, n_epochs=[60,10,5],
                    batch_size=128, n_hidden=128, n_hiddenLayers=1,
                    verbose=True, activation='tanh', momentum=0.9)
# Out:
# Data already unpacked
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# epoch 1, minibatch 312/312, validation error 78.345353 %
#      epoch 1, minibatch 312/312, test error of best model 78.104968 %
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# epoch 2, minibatch 312/312, validation error 65.574920 %
#      epoch 2, minibatch 312/312, test error of best model 64.603365 %
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# epoch 3, minibatch 312/312, validation error 61.217949 %
#      epoch 3, minibatch 312/312, test error of best model 60.827324 %
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# epoch 4, minibatch 312/312, validation error 54.807692 %
#      epoch 4, minibatch 312/312, test error of best model 54.226763 %
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# ...
